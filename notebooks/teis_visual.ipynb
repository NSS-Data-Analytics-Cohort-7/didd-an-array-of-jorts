# %%
import pandas as pd
import openpyxl as opx
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
teisdf = pd.read_excel('../data/teisdata.xlsx', 
                             sheet_name=['ECO with Exit21-22', 'Elig Timeline Rpt 2018-2022'])

ecodf = teisdf.get('ECO with Exit21-22')
eligdf = teisdf.get('Elig Timeline Rpt 2018-2022')

# %% [markdown]
# Entry Score 1

# %%
ent1ss = ecodf[ecodf['Ent SOCIAL_SCALE'] == 1]
ent1ks = ecodf[ecodf['Ent KNOWLEDGE_SCALE'] == 1]
ent1aas = ecodf[ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 1]

exit1ss = ecodf[ecodf['Exit SOCIAL_SCALE'] == 1] 
exit1ks = ecodf[ecodf['Exit KNOWLEDGE_SCALE'] == 1]
exit1aas = ecodf[ecodf['Exit APPROPRIATE_ACTION_SCALE'] == 3]


# dataframe of children who entered and exited the program with a 6 in the social, knowledge, or appropriate action scale
nochangess1 = ecodf[(ecodf['Ent SOCIAL_SCALE'] == 1) & (ecodf['Exit SOCIAL_SCALE'] == 1)]
nochangeks1 = ecodf[(ecodf['Ent KNOWLEDGE_SCALE'] == 1) & (ecodf['Exit KNOWLEDGE_SCALE'] == 1)]
nochangeaas1 = ecodf[(ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 1) & (ecodf['Exit APPROPRIATE_ACTION_SCALE'] == 1)]

# dataframe of children whos scores decreased in the social, knowledge, or appropriate action scale
decreasess1 = ecodf[(ecodf['Ent SOCIAL_SCALE'] == 1) & (ecodf['Exit SOCIAL_SCALE'] < 1)]
decreaseks1 = ecodf[(ecodf['Ent KNOWLEDGE_SCALE'] == 1) & (ecodf['Exit KNOWLEDGE_SCALE'] < 1)]
decreaseaas1 = ecodf[(ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 1) & (ecodf['Exit APPROPRIATE_ACTION_SCALE'] < 1)]

# dataframe of children whos scores increased in the social, knowledge, or appropriate action scale
increasess1 = ecodf[(ecodf['Ent SOCIAL_SCALE'] == 1) & (ecodf['Exit SOCIAL_SCALE'] > 1)]
increaseks1 = ecodf[(ecodf['Ent KNOWLEDGE_SCALE'] == 1) & (ecodf['Exit KNOWLEDGE_SCALE'] > 1)]
increaseaas1 = ecodf[(ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 1) & (ecodf['Exit APPROPRIATE_ACTION_SCALE'] > 1)]



print(nochangess1['Ent SOCIAL_SCALE'].count()/ent1ss['Ent SOCIAL_SCALE'].count() *100)
print(nochangeks1['Ent KNOWLEDGE_SCALE'].count()/ent1ks['Ent KNOWLEDGE_SCALE'].count() *100)
print(nochangeaas1['Ent APPROPRIATE_ACTION_SCALE'].count()/ent1aas['Ent APPROPRIATE_ACTION_SCALE'].count() *100)

print(decreasess1['Ent SOCIAL_SCALE'].count()/ent1ss['Ent SOCIAL_SCALE'].count() *100)
print(decreaseks1['Ent KNOWLEDGE_SCALE'].count()/ent1ks['Ent KNOWLEDGE_SCALE'].count() *100)
print(decreaseaas1['Ent APPROPRIATE_ACTION_SCALE'].count()/ent1aas['Ent APPROPRIATE_ACTION_SCALE'].count() *100)

print(increasess1['Ent SOCIAL_SCALE'].count()/ent1ss['Ent SOCIAL_SCALE'].count() *100)
print(increaseks1['Ent KNOWLEDGE_SCALE'].count()/ent1ks['Ent KNOWLEDGE_SCALE'].count() *100)
print(increaseaas1['Ent APPROPRIATE_ACTION_SCALE'].count()/ent1aas['Ent APPROPRIATE_ACTION_SCALE'].count() *100)



# dataframe showing average program length based on whether social status score increased, decreased or had no change
avgprogramlenssin1 = increasess1['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenssde1 = decreasess1['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenssnc1 = nochangess1['Days btw I-IFSP to Exit ECO'].median()

# dataframe showing average program length based on whether knowledge status score increased, decreased or had no change
avgprogramlenksin1 = increaseks1['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenksde1 = decreaseks1['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenksnc1 = nochangeks1['Days btw I-IFSP to Exit ECO'].median()

# dataframe showing average program length based on whether acceptable action score increased, decreased or had no change
avgprogramlenaasin1 = increaseaas1['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenaasde1 = decreaseaas1['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenaasnc1 = nochangeaas1['Days btw I-IFSP to Exit ECO'].median()

print(avgprogramlenssin1)
print(avgprogramlenssde1)
print(avgprogramlenssnc1)
      
print(avgprogramlenksin1)
print(avgprogramlenksde1)
print(avgprogramlenksnc1)
      
print(avgprogramlenaasin1)
print(avgprogramlenaasde1)
print(avgprogramlenaasnc1)
# Out:
# 42.125678820791315
# 47.85407725321888
# 32.416502946954814
# 0.0
# 0.0
# 0.0
# 57.874321179208685
# 52.14592274678112
# 67.58349705304518
# 364.0
# nan
# 317.0
# 480.0
# nan
# 196.0
# 693.0
# nan
# 362.0

# %% [markdown]
# Entry Score 2

# %%
ent2ss = ecodf[ecodf['Ent SOCIAL_SCALE'] == 2]
ent2ks = ecodf[ecodf['Ent KNOWLEDGE_SCALE'] == 2]
ent2aas = ecodf[ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 2]

exit2ss = ecodf[ecodf['Exit SOCIAL_SCALE'] == 2] 
exit2ks = ecodf[ecodf['Exit KNOWLEDGE_SCALE'] == 2]
exit2aas = ecodf[ecodf['Exit APPROPRIATE_ACTION_SCALE'] == 2]


# dataframe of children who entered and exited the program with a 6 in the social, knowledge, or appropriate action scale
nochangess2 = ecodf[(ecodf['Ent SOCIAL_SCALE'] == 2) & (ecodf['Exit SOCIAL_SCALE'] == 2)]
nochangeks2 = ecodf[(ecodf['Ent KNOWLEDGE_SCALE'] == 2) & (ecodf['Exit KNOWLEDGE_SCALE'] == 2)]
nochangeaas2 = ecodf[(ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 2) & (ecodf['Exit APPROPRIATE_ACTION_SCALE'] == 2)]

# dataframe of children whos scores decreased in the social, knowledge, or appropriate action scale
decreasess2 = ecodf[(ecodf['Ent SOCIAL_SCALE'] == 2) & (ecodf['Exit SOCIAL_SCALE'] < 2)]
decreaseks2 = ecodf[(ecodf['Ent KNOWLEDGE_SCALE'] == 2) & (ecodf['Exit KNOWLEDGE_SCALE'] < 2)]
decreaseaas2 = ecodf[(ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 2) & (ecodf['Exit APPROPRIATE_ACTION_SCALE'] < 2)]

# dataframe of children whos scores increased in the social, knowledge, or appropriate action scale
increasess2 = ecodf[(ecodf['Ent SOCIAL_SCALE'] == 2) & (ecodf['Exit SOCIAL_SCALE'] > 3)]
increaseks2 = ecodf[(ecodf['Ent KNOWLEDGE_SCALE'] == 2) & (ecodf['Exit KNOWLEDGE_SCALE'] > 3)]
increaseaas2 = ecodf[(ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 2) & (ecodf['Exit APPROPRIATE_ACTION_SCALE'] > 3)]



print(nochangess2['Ent SOCIAL_SCALE'].count()/ent2ss['Ent SOCIAL_SCALE'].count() *100)
print(nochangeks2['Ent KNOWLEDGE_SCALE'].count()/ent2ks['Ent KNOWLEDGE_SCALE'].count() *100)
print(nochangeaas2['Ent APPROPRIATE_ACTION_SCALE'].count()/ent2aas['Ent APPROPRIATE_ACTION_SCALE'].count() *100)

print(decreasess2['Ent SOCIAL_SCALE'].count()/ent2ss['Ent SOCIAL_SCALE'].count() *100)
print(decreaseks2['Ent KNOWLEDGE_SCALE'].count()/ent2ks['Ent KNOWLEDGE_SCALE'].count() *100)
print(decreaseaas2['Ent APPROPRIATE_ACTION_SCALE'].count()/ent2aas['Ent APPROPRIATE_ACTION_SCALE'].count() *100)

print(increasess2['Ent SOCIAL_SCALE'].count()/ent2ss['Ent SOCIAL_SCALE'].count() *100)
print(increaseks2['Ent KNOWLEDGE_SCALE'].count()/ent2ks['Ent KNOWLEDGE_SCALE'].count() *100)
print(increaseaas2['Ent APPROPRIATE_ACTION_SCALE'].count()/ent2aas['Ent APPROPRIATE_ACTION_SCALE'].count() *100)



# dataframe showing average program length based on whether social status score increased, decreased or had no change
avgprogramlenssin2 = increasess2['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenssde2 = decreasess2['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenssnc2 = nochangess2['Days btw I-IFSP to Exit ECO'].median()

# dataframe showing average program length based on whether knowledge status score increased, decreased or had no change
avgprogramlenksin2 = increaseks2['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenksde2 = decreaseks2['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenksnc2 = nochangeks2['Days btw I-IFSP to Exit ECO'].median()

# dataframe showing average program length based on whether acceptable action score increased, decreased or had no change
avgprogramlenaasin2 = increaseaas2['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenaasde2 = decreaseaas2['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenaasnc2 = nochangeaas2['Days btw I-IFSP to Exit ECO'].median()

print(avgprogramlenssin2)
print(avgprogramlenssde2)
print(avgprogramlenssnc2)
      
print(avgprogramlenksin2)
print(avgprogramlenksde2)
print(avgprogramlenksnc2)
    
print(avgprogramlenaasin2)
print(avgprogramlenaasde2)
print(avgprogramlenaasnc2)
# Out:
# 14.462416745956233
# 17.46641074856046
# 14.424410540915394
# 8.372978116079924
# 32.05374280230326
# 11.373092926490985
# 56.99333967649858
# 31.861804222648754
# 63.52288488210819
# 559.0
# 388.5
# 226.5
# 356.5
# 349.0
# 180.0
# 539.0
# 425.0
# 184.5

# %% [markdown]
# Entry Score 3

# %%
ent3ss = ecodf[ecodf['Ent SOCIAL_SCALE'] == 3]
ent3ks = ecodf[ecodf['Ent KNOWLEDGE_SCALE'] == 3]
ent3aas = ecodf[ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 3]

exit3ss = ecodf[ecodf['Exit SOCIAL_SCALE'] == 3] 
exit3ks = ecodf[ecodf['Exit KNOWLEDGE_SCALE'] == 3]
exit3aas = ecodf[ecodf['Exit APPROPRIATE_ACTION_SCALE'] == 3]


# dataframe of children who entered and exited the program with a 6 in the social, knowledge, or appropriate action scale
nochangess3 = ecodf[(ecodf['Ent SOCIAL_SCALE'] == 3) & (ecodf['Exit SOCIAL_SCALE'] == 3)]
nochangeks3 = ecodf[(ecodf['Ent KNOWLEDGE_SCALE'] == 3) & (ecodf['Exit KNOWLEDGE_SCALE'] == 3)]
nochangeaas3 = ecodf[(ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 3) & (ecodf['Exit APPROPRIATE_ACTION_SCALE'] == 3)]

# dataframe of children whos scores decreased in the social, knowledge, or appropriate action scale
decreasess3 = ecodf[(ecodf['Ent SOCIAL_SCALE'] == 3) & (ecodf['Exit SOCIAL_SCALE'] < 3)]
decreaseks3 = ecodf[(ecodf['Ent KNOWLEDGE_SCALE'] == 3) & (ecodf['Exit KNOWLEDGE_SCALE'] < 3)]
decreaseaas3 = ecodf[(ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 3) & (ecodf['Exit APPROPRIATE_ACTION_SCALE'] < 3)]

# dataframe of children whos scores increased in the social, knowledge, or appropriate action scale
increasess3 = ecodf[(ecodf['Ent SOCIAL_SCALE'] == 3) & (ecodf['Exit SOCIAL_SCALE'] > 3)]
increaseks3 = ecodf[(ecodf['Ent KNOWLEDGE_SCALE'] == 3) & (ecodf['Exit KNOWLEDGE_SCALE'] > 3)]
increaseaas3 = ecodf[(ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 3) & (ecodf['Exit APPROPRIATE_ACTION_SCALE'] > 3)]



print(nochangess3['Ent SOCIAL_SCALE'].count()/ent3ss['Ent SOCIAL_SCALE'].count() *100)
print(nochangeks3['Ent KNOWLEDGE_SCALE'].count()/ent3ks['Ent KNOWLEDGE_SCALE'].count() *100)
print(nochangeaas3['Ent APPROPRIATE_ACTION_SCALE'].count()/ent3aas['Ent APPROPRIATE_ACTION_SCALE'].count() *100)

print(decreasess3['Ent SOCIAL_SCALE'].count()/ent3ss['Ent SOCIAL_SCALE'].count() *100)
print(decreaseks3['Ent KNOWLEDGE_SCALE'].count()/ent3ks['Ent KNOWLEDGE_SCALE'].count() *100)
print(decreaseaas3['Ent APPROPRIATE_ACTION_SCALE'].count()/ent3aas['Ent APPROPRIATE_ACTION_SCALE'].count() *100)

print(increasess3['Ent SOCIAL_SCALE'].count()/ent3ss['Ent SOCIAL_SCALE'].count() *100)
print(increaseks3['Ent KNOWLEDGE_SCALE'].count()/ent3ks['Ent KNOWLEDGE_SCALE'].count() *100)
print(increaseaas3['Ent APPROPRIATE_ACTION_SCALE'].count()/ent3aas['Ent APPROPRIATE_ACTION_SCALE'].count() *100)



# dataframe showing average program length based on whether social status score increased, decreased or had no change
avgprogramlenssin3 = increasess3['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenssde3 = decreasess3['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenssnc3 = nochangess3['Days btw I-IFSP to Exit ECO'].median()

# dataframe showing average program length based on whether knowledge status score increased, decreased or had no change
avgprogramlenksin3 = increaseks3['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenksde3 = decreaseks3['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenksnc3 = nochangeks3['Days btw I-IFSP to Exit ECO'].median()

# dataframe showing average program length based on whether acceptable action score increased, decreased or had no change
avgprogramlenaasin3 = increaseaas3['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenaasde3 = decreaseaas3['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenaasnc3 = nochangeaas3['Days btw I-IFSP to Exit ECO'].median()

print(avgprogramlenssin3)
print(avgprogramlenssde3)
print(avgprogramlenssnc3)
      
print(avgprogramlenksin3)
print(avgprogramlenksde3)
print(avgprogramlenksnc3)
      
print(avgprogramlenaasin3)
print(avgprogramlenaasde3)
print(avgprogramlenaasnc3)
# Out:
# 19.790828640386163
# 31.68023686158401
# 19.797687861271676
# 8.608205953338697
# 27.01702442635085
# 13.294797687861271
# 71.60096540627514
# 41.302738712065135
# 66.90751445086705
# 357.0
# 352.0
# 183.0
# 336.0
# 357.0
# 185.5
# 352.0
# 347.5
# 203.0

# %% [markdown]
# Entry Score 4

# %%
ent4ss = ecodf[ecodf['Ent SOCIAL_SCALE'] == 4]
ent4ks = ecodf[ecodf['Ent KNOWLEDGE_SCALE'] == 4]
ent4aas = ecodf[ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 4]

exit4ss = ecodf[ecodf['Exit SOCIAL_SCALE'] == 4] 
exit4ks = ecodf[ecodf['Exit KNOWLEDGE_SCALE'] == 4]
exit4aas = ecodf[ecodf['Exit APPROPRIATE_ACTION_SCALE'] == 4]


# dataframe of children who entered and exited the program with a 6 in the social, knowledge, or appropriate action scale
nochangess4 = ecodf[(ecodf['Ent SOCIAL_SCALE'] == 4) & (ecodf['Exit SOCIAL_SCALE'] == 4)]
nochangeks4 = ecodf[(ecodf['Ent KNOWLEDGE_SCALE'] == 4) & (ecodf['Exit KNOWLEDGE_SCALE'] == 4)]
nochangeaas4 = ecodf[(ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 4) & (ecodf['Exit APPROPRIATE_ACTION_SCALE'] == 4)]

# dataframe of children whos scores decreased in the social, knowledge, or appropriate action scale
decreasess4 = ecodf[(ecodf['Ent SOCIAL_SCALE'] == 4) & (ecodf['Exit SOCIAL_SCALE'] < 4)]
decreaseks4 = ecodf[(ecodf['Ent KNOWLEDGE_SCALE'] == 4) & (ecodf['Exit KNOWLEDGE_SCALE'] < 4)]
decreaseaas4 = ecodf[(ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 4) & (ecodf['Exit APPROPRIATE_ACTION_SCALE'] < 4)]

# dataframe of children whos scores increased in the social, knowledge, or appropriate action scale
increasess4 = ecodf[(ecodf['Ent SOCIAL_SCALE'] == 4) & (ecodf['Exit SOCIAL_SCALE'] > 4)]
increaseks4 = ecodf[(ecodf['Ent KNOWLEDGE_SCALE'] == 4) & (ecodf['Exit KNOWLEDGE_SCALE'] > 4)]
increaseaas4 = ecodf[(ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 4) & (ecodf['Exit APPROPRIATE_ACTION_SCALE'] > 4)]



print(nochangess4['Ent SOCIAL_SCALE'].count()/ent4ss['Ent SOCIAL_SCALE'].count() *100)
print(nochangeks4['Ent KNOWLEDGE_SCALE'].count()/ent4ks['Ent KNOWLEDGE_SCALE'].count() *100)
print(nochangeaas4['Ent APPROPRIATE_ACTION_SCALE'].count()/ent4aas['Ent APPROPRIATE_ACTION_SCALE'].count() *100)

print(decreasess4['Ent SOCIAL_SCALE'].count()/ent4ss['Ent SOCIAL_SCALE'].count() *100)
print(decreaseks4['Ent KNOWLEDGE_SCALE'].count()/ent4ks['Ent KNOWLEDGE_SCALE'].count() *100)
print(decreaseaas4['Ent APPROPRIATE_ACTION_SCALE'].count()/ent4aas['Ent APPROPRIATE_ACTION_SCALE'].count() *100)

print(increasess4['Ent SOCIAL_SCALE'].count()/ent4ss['Ent SOCIAL_SCALE'].count() *100)
print(increaseks4['Ent KNOWLEDGE_SCALE'].count()/ent4ks['Ent KNOWLEDGE_SCALE'].count() *100)
print(increaseaas4['Ent APPROPRIATE_ACTION_SCALE'].count()/ent4aas['Ent APPROPRIATE_ACTION_SCALE'].count() *100)



# dataframe showing average program length based on whether social status score increased, decreased or had no change
avgprogramlenssin4 = increasess4['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenssde4 = decreasess4['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenssnc4 = nochangess4['Days btw I-IFSP to Exit ECO'].median()

# dataframe showing average program length based on whether knowledge status score increased, decreased or had no change
avgprogramlenksin4 = increaseks4['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenksde4 = decreaseks4['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenksnc4 = nochangeks4['Days btw I-IFSP to Exit ECO'].median()

# dataframe showing average program length based on whether acceptable action score increased, decreased or had no change
avgprogramlenaasin4 = increaseaas4['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenaasde4 = decreaseaas4['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenaasnc4 = nochangeaas4['Days btw I-IFSP to Exit ECO'].median()

print(avgprogramlenssin4)
print(avgprogramlenssde4)
print(avgprogramlenssnc4)
      
print(avgprogramlenksin4)
print(avgprogramlenksde4)
print(avgprogramlenksnc4)
      
print(avgprogramlenaasin4)
print(avgprogramlenaasde4)
print(avgprogramlenaasnc4)
# Out:
# 14.339622641509434
# 18.231441048034934
# 22.284434490481523
# 10.754716981132075
# 30.240174672489083
# 16.90929451287794
# 74.90566037735849
# 51.52838427947598
# 60.806270996640535
# 345.0
# 351.0
# 189.0
# 348.0
# 364.0
# 234.0
# 342.0
# 337.0
# 184.0

# %% [markdown]
# Entry Score 5

# %%
ent5ss = ecodf[ecodf['Ent SOCIAL_SCALE'] == 5]
ent5ks = ecodf[ecodf['Ent KNOWLEDGE_SCALE'] == 5]
ent5aas = ecodf[ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 5]

exit5ss = ecodf[ecodf['Exit SOCIAL_SCALE'] == 5] 
exit5ks = ecodf[ecodf['Exit KNOWLEDGE_SCALE'] == 5]
exit5aas = ecodf[ecodf['Exit APPROPRIATE_ACTION_SCALE'] == 5]


# dataframe of children who entered and exited the program with a 6 in the social, knowledge, or appropriate action scale
nochangess5 = ecodf[(ecodf['Ent SOCIAL_SCALE'] == 5) & (ecodf['Exit SOCIAL_SCALE'] == 5)]
nochangeks5 = ecodf[(ecodf['Ent KNOWLEDGE_SCALE'] == 5) & (ecodf['Exit KNOWLEDGE_SCALE'] == 5)]
nochangeaas5 = ecodf[(ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 5) & (ecodf['Exit APPROPRIATE_ACTION_SCALE'] == 5)]

# dataframe of children whos scores decreased in the social, knowledge, or appropriate action scale
decreasess5 = ecodf[(ecodf['Ent SOCIAL_SCALE'] == 5) & (ecodf['Exit SOCIAL_SCALE'] < 5)]
decreaseks5 = ecodf[(ecodf['Ent KNOWLEDGE_SCALE'] == 5) & (ecodf['Exit KNOWLEDGE_SCALE'] < 5)]
decreaseaas5 = ecodf[(ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 5) & (ecodf['Exit APPROPRIATE_ACTION_SCALE'] < 5)]

# dataframe of children whos scores increased in the social, knowledge, or appropriate action scale
increasess5 = ecodf[(ecodf['Ent SOCIAL_SCALE'] == 5) & (ecodf['Exit SOCIAL_SCALE'] > 5)]
increaseks5 = ecodf[(ecodf['Ent KNOWLEDGE_SCALE'] == 5) & (ecodf['Exit KNOWLEDGE_SCALE'] > 5)]
increaseaas5 = ecodf[(ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 5) & (ecodf['Exit APPROPRIATE_ACTION_SCALE'] > 5)]



print(nochangess5['Ent SOCIAL_SCALE'].count()/ent5ss['Ent SOCIAL_SCALE'].count() *100)
print(nochangeks5['Ent KNOWLEDGE_SCALE'].count()/ent5ks['Ent KNOWLEDGE_SCALE'].count() *100)
print(nochangeaas5['Ent APPROPRIATE_ACTION_SCALE'].count()/ent5aas['Ent APPROPRIATE_ACTION_SCALE'].count() *100)

print(decreasess5['Ent SOCIAL_SCALE'].count()/ent5ss['Ent SOCIAL_SCALE'].count() *100)
print(decreaseks5['Ent KNOWLEDGE_SCALE'].count()/ent5ks['Ent KNOWLEDGE_SCALE'].count() *100)
print(decreaseaas5['Ent APPROPRIATE_ACTION_SCALE'].count()/ent5aas['Ent APPROPRIATE_ACTION_SCALE'].count() *100)

print(increasess5['Ent SOCIAL_SCALE'].count()/ent5ss['Ent SOCIAL_SCALE'].count() *100)
print(increaseks5['Ent KNOWLEDGE_SCALE'].count()/ent5ks['Ent KNOWLEDGE_SCALE'].count() *100)
print(increaseaas5['Ent APPROPRIATE_ACTION_SCALE'].count()/ent5aas['Ent APPROPRIATE_ACTION_SCALE'].count() *100)



# dataframe showing average program length based on whether social status score increased, decreased or had no change
avgprogramlenssin5 = increasess5['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenssde5 = decreasess5['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenssnc5 = nochangess5['Days btw I-IFSP to Exit ECO'].median()

# dataframe showing average program length based on whether knowledge status score increased, decreased or had no change
avgprogramlenksin5 = increaseks5['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenksde5 = decreaseks5['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenksnc5 = nochangeks5['Days btw I-IFSP to Exit ECO'].median()

# dataframe showing average program length based on whether acceptable action score increased, decreased or had no change
avgprogramlenaasin5 = increaseaas5['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenaasde5 = decreaseaas5['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenaasnc5 = nochangeaas5['Days btw I-IFSP to Exit ECO'].median()

print(avgprogramlenssin5)
print(avgprogramlenssde5)
print(avgprogramlenssnc5)
      
print(avgprogramlenksin5)
print(avgprogramlenksde5)
print(avgprogramlenksnc5)
      
print(avgprogramlenaasin5)
print(avgprogramlenaasde5)
print(avgprogramlenaasnc5)
# Out:
# 21.91358024691358
# 21.83206106870229
# 13.54515050167224
# 6.944444444444445
# 29.00763358778626
# 22.40802675585284
# 71.14197530864197
# 49.16030534351145
# 64.04682274247492
# 335.0
# 325.0
# 182.0
# 353.0
# 501.5
# 324.5
# 335.0
# 343.0
# 184.0

# %% [markdown]
# Entry Score 6

# %%
# dataframe of children who entered the program with a 6 in either the social, knowledge, or appropriate action scale
ent6ss = ecodf[ecodf['Ent SOCIAL_SCALE'] == 6]
ent6ks = ecodf[ecodf['Ent KNOWLEDGE_SCALE'] == 6]
ent6aas = ecodf[ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 6]

# dataframe of children who exited the program with a 6 in either the social, knowledge, or appropriate action scale 
exit6ss = ecodf[ecodf['Exit SOCIAL_SCALE'] == 6] 
exit6ks = ecodf[ecodf['Exit KNOWLEDGE_SCALE'] == 6]
exit6aas = ecodf[ecodf['Exit APPROPRIATE_ACTION_SCALE'] == 6]

# dataframe of children who entered and exited the program with a 6 in the social, knowledge, or appropriate action scale
nochangess = ecodf[(ecodf['Ent SOCIAL_SCALE'] == 6) & (ecodf['Exit SOCIAL_SCALE'] == 6)]
nochangeks = ecodf[(ecodf['Ent KNOWLEDGE_SCALE'] == 6) & (ecodf['Exit KNOWLEDGE_SCALE'] == 6)]
nochangeaas = ecodf[(ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 6) & (ecodf['Exit APPROPRIATE_ACTION_SCALE'] == 6)]

# dataframe of children whos scores decreased in the social, knowledge, or appropriate action scale
decreasess = ecodf[(ecodf['Ent SOCIAL_SCALE'] == 6) & (ecodf['Exit SOCIAL_SCALE'] < 6)]
decreaseks = ecodf[(ecodf['Ent KNOWLEDGE_SCALE'] == 6) & (ecodf['Exit KNOWLEDGE_SCALE'] < 6)]
decreaseaas = ecodf[(ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 6) & (ecodf['Exit APPROPRIATE_ACTION_SCALE'] < 6)]

# dataframe of children whos scores increased in the social, knowledge, or appropriate action scale
increasess = ecodf[(ecodf['Ent SOCIAL_SCALE'] == 6) & (ecodf['Exit SOCIAL_SCALE'] > 6)]
increaseks = ecodf[(ecodf['Ent KNOWLEDGE_SCALE'] == 6) & (ecodf['Exit KNOWLEDGE_SCALE'] > 6)]
increaseaas = ecodf[(ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 6) & (ecodf['Exit APPROPRIATE_ACTION_SCALE'] > 6)]


print(decreasess['Ent SOCIAL_SCALE'].count()/ent6ss['Ent SOCIAL_SCALE'].count() *100)
print(decreaseks['Ent KNOWLEDGE_SCALE'].count()/ent6ks['Ent KNOWLEDGE_SCALE'].count() *100)
print(decreaseaas['Ent APPROPRIATE_ACTION_SCALE'].count()/ent6aas['Ent APPROPRIATE_ACTION_SCALE'].count() *100)


print(increasess['Ent SOCIAL_SCALE'].count()/ent6ss['Ent SOCIAL_SCALE'].count() *100)
print(increaseks['Ent KNOWLEDGE_SCALE'].count()/ent6ks['Ent KNOWLEDGE_SCALE'].count() *100)
print(increaseaas['Ent APPROPRIATE_ACTION_SCALE'].count()/ent6aas['Ent APPROPRIATE_ACTION_SCALE'].count() *100)


avgprogramlenssin = increasess['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenssde = decreasess['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenssnc = nochangess['Days btw I-IFSP to Exit ECO'].median()

# dataframe showing average program length based on whether knowledge status score increased, decreased or had no change
avgprogramlenksin = increaseks['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenksde = decreaseks['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenksnc = nochangeks['Days btw I-IFSP to Exit ECO'].median()

# dataframe showing average program length based on whether acceptable action score increased, decreased or had no change
avgprogramlenaasin = increaseaas['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenaasde = decreaseaas['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenaasnc = nochangeaas['Days btw I-IFSP to Exit ECO'].median()


print(avgprogramlenssin)
print(avgprogramlenssde)
print(avgprogramlenssnc)

print(avgprogramlenksin)
print(avgprogramlenksde)
print(avgprogramlenksnc)

print(avgprogramlenaasin)
print(avgprogramlenaasde)
print(avgprogramlenaasnc)
# Out:
# 6.235011990407674
# 20.60889929742389
# 16.691285081240768
# 59.95203836930456
# 52.69320843091335
# 56.12998522895125
# 194.0
# 319.0
# 182.0
# 338.0
# 357.0
# 189.0
# 200.5
# 340.0
# 182.5

# %% [markdown]
# Entry Score 7

# %%
ent7ss = ecodf[ecodf['Ent SOCIAL_SCALE'] == 7]
ent7ks = ecodf[ecodf['Ent KNOWLEDGE_SCALE'] == 7]
ent7aas = ecodf[ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 7]

exit7ss = ecodf[ecodf['Exit SOCIAL_SCALE'] == 7] 
exit7ks = ecodf[ecodf['Exit KNOWLEDGE_SCALE'] == 7]
exit7aas = ecodf[ecodf['Exit APPROPRIATE_ACTION_SCALE'] == 7]


# dataframe of children who entered and exited the program with a 6 in the social, knowledge, or appropriate action scale
nochangess7 = ecodf[(ecodf['Ent SOCIAL_SCALE'] == 7) & (ecodf['Exit SOCIAL_SCALE'] == 7)]
nochangeks7 = ecodf[(ecodf['Ent KNOWLEDGE_SCALE'] == 7) & (ecodf['Exit KNOWLEDGE_SCALE'] == 7)]
nochangeaas7 = ecodf[(ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 7) & (ecodf['Exit APPROPRIATE_ACTION_SCALE'] == 7)]

# dataframe of children whos scores decreased in the social, knowledge, or appropriate action scale
decreasess7 = ecodf[(ecodf['Ent SOCIAL_SCALE'] == 7) & (ecodf['Exit SOCIAL_SCALE'] < 7)]
decreaseks7 = ecodf[(ecodf['Ent KNOWLEDGE_SCALE'] == 7) & (ecodf['Exit KNOWLEDGE_SCALE'] < 7)]
decreaseaas7 = ecodf[(ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 7) & (ecodf['Exit APPROPRIATE_ACTION_SCALE'] < 7)]

# dataframe of children whos scores increased in the social, knowledge, or appropriate action scale
increasess7 = ecodf[(ecodf['Ent SOCIAL_SCALE'] == 7) & (ecodf['Exit SOCIAL_SCALE'] > 7)]
increaseks7 = ecodf[(ecodf['Ent KNOWLEDGE_SCALE'] == 7) & (ecodf['Exit KNOWLEDGE_SCALE'] > 7)]
increaseaas7 = ecodf[(ecodf['Ent APPROPRIATE_ACTION_SCALE'] == 7) & (ecodf['Exit APPROPRIATE_ACTION_SCALE'] > 7)]



print(nochangess7['Ent SOCIAL_SCALE'].count()/ent7ss['Ent SOCIAL_SCALE'].count() *100)
print(nochangeks7['Ent KNOWLEDGE_SCALE'].count()/ent7ks['Ent KNOWLEDGE_SCALE'].count() *100)
print(nochangeaas7['Ent APPROPRIATE_ACTION_SCALE'].count()/ent7aas['Ent APPROPRIATE_ACTION_SCALE'].count() *100)

print(decreasess7['Ent SOCIAL_SCALE'].count()/ent7ss['Ent SOCIAL_SCALE'].count() *100)
print(decreaseks7['Ent KNOWLEDGE_SCALE'].count()/ent7ks['Ent KNOWLEDGE_SCALE'].count() *100)
print(decreaseaas7['Ent APPROPRIATE_ACTION_SCALE'].count()/ent7aas['Ent APPROPRIATE_ACTION_SCALE'].count() *100)

print(increasess7['Ent SOCIAL_SCALE'].count()/ent7ss['Ent SOCIAL_SCALE'].count() *100)
print(increaseks7['Ent KNOWLEDGE_SCALE'].count()/ent7ks['Ent KNOWLEDGE_SCALE'].count() *100)
print(increaseaas7['Ent APPROPRIATE_ACTION_SCALE'].count()/ent7aas['Ent APPROPRIATE_ACTION_SCALE'].count() *100)



# dataframe showing average program length based on whether social status score increased, decreased or had no change
avgprogramlenssin7 = increasess7['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenssde7 = decreasess7['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenssnc7 = nochangess7['Days btw I-IFSP to Exit ECO'].median()

# dataframe showing average program length based on whether knowledge status score increased, decreased or had no change
avgprogramlenksin7 = increaseks7['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenksde7 = decreaseks7['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenksnc7 = nochangeks7['Days btw I-IFSP to Exit ECO'].median()

# dataframe showing average program length based on whether acceptable action score increased, decreased or had no change
avgprogramlenaasin7 = increaseaas7['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenaasde7 = decreaseaas7['Days btw I-IFSP to Exit ECO'].median()
avgprogramlenaasnc7 = nochangeaas7['Days btw I-IFSP to Exit ECO'].median()

print(avgprogramlenssin7)
print(avgprogramlenssde7)
print(avgprogramlenssnc7)
      
print(avgprogramlenksin7)
print(avgprogramlenksde7)
print(avgprogramlenksnc7)
      
print(avgprogramlenaasin7)
print(avgprogramlenaasde7)
print(avgprogramlenaasnc7)
# Out:
# 88.39779005524862
# 85.22727272727273
# 85.29411764705883
# 11.602209944751381
# 14.772727272727273
# 14.705882352941178
# 0.0
# 0.0
# 0.0
# nan
# 200.0
# 187.5
# nan
# 350.0
# 186.0
# nan
# 349.0
# 250.0

# %%
fig, ax = plt.subplots()

size = 0.3
vals = np.array([[60., 32.,], [37., 40.], [29., 10.]])

cmap = plt.colormaps["tab20c"]
outer_colors = cmap(np.arange(3)*4)
inner_colors = cmap([1, 2, 5, 6, 9, 10])

ax.pie(vals.sum(axis=1), radius=1, colors=outer_colors,
       wedgeprops=dict(width=size, edgecolor='w'))

ax.pie(vals.flatten(), radius=1-size, colors=inner_colors,
       wedgeprops=dict(width=size, edgecolor='w'))

ax.set(aspect="equal", title='Pie plot with `ax.pie`')
plt.show()

# %%
source_data={'students':['No Change','Increased'],
'social_scale':[42.125678820791315,57.874321179208685],
'knowledge_scale':[47.85407725321888,52.14592274678112],
'appropriate_action_scale':[32.416502946954814,67.58349705304518]}

# Segregating the raw data into usuable form
df=pd.DataFrame(source_data,columns=
['students','social_scale','knowledge_scale','appropriate_action_scale'])
# df['cumulative_score']=df['social_scale']+df['knowledge_scale']
# +df['appropriate_action_scale']

# Seperating the sub-parts of the given data
x1= df.iloc[0:3,1]
x2= df.iloc[0:3,2]
x3= df.iloc[0:3,3]

# Setting figure colors
cmap = plt.get_cmap("tab20c")
# outer_colors = cmap(np.arange(3)*4)
outer_colors = cmap(np.array([1,5,9]))
inner_colors = cmap(np.array([1,5,9]))
inner_colors1 = cmap(np.array([1,5,9]))
# Setting the size of the figure
plt.figure(figsize=(8,6))

# Plotting the outer pie
plt.pie(x1, labels = df.iloc[0:3, 0], 
       startangle=90, pctdistance =0.88 ,colors=outer_colors,
       autopct = '%1.1f%%', radius= 1.0, labeldistance=1.05,
       textprops ={'fontsize':13},
       wedgeprops = {'linewidth' : 3, 'edgecolor' : "w" } )

# PLotting the inner pie
plt.pie(x2,startangle=90, pctdistance =.85,colors=inner_colors,
        autopct = '%1.1f%%',radius= 0.70,
       textprops ={'fontsize':13}, 
       wedgeprops = {'linewidth' : 3, 'edgecolor' : "w" } )

# PLotting the inner pie2
plt.pie(x3,startangle=90, pctdistance =.50,colors=inner_colors1,
        autopct = '%1.1f%%',radius= 0.45,
        textprops ={'fontsize':13}, 
       wedgeprops = {'linewidth' : 3, 'edgecolor' : "w" } )
# 'fontweight': 'bold' ,
# Creating the donut shape for the pie
centre_circle = plt.Circle((0,0), 0.25, fc='white')
fig= plt.gcf()
fig.gca().add_artist(centre_circle) # adding the centre circle

# Plotting the pie 
plt.axis('equal')  # equal aspect ratio
# plt.legend(loc=3, fontsize =10)
# plt.legend(['Outer Ring (Social Scale)', 'Middle Ring (Knowledge Scale)', 'Inner Ring (Appropriate Action Scale)'])
plt.title('Change in Entry Score (1)\n\nOuter Ring - Social Scale\nMiddle Ring - Knowledge Scale\nInner Ring - Appropriate Action Scale', fontweight='bold')
plt.tight_layout()
plt.show()

# %%
source_data={'students':['No Change','Decreased','Increased'],
'social_scale':[14.462416745956233,8.372978116079924,56.99333967649858],
'knowledge_scale':[17.46641074856046,32.05374280230326,31.861804222648754],
'appropriate_action_scale':[14.424410540915394,11.373092926490985,63.52288488210819]}

# Segregating the raw data into usuable form
df=pd.DataFrame(source_data,columns=
['students','social_scale','knowledge_scale','appropriate_action_scale'])
# df['cumulative_score']=df['social_scale']+df['knowledge_scale']
# +df['appropriate_action_scale']

# Seperating the sub-parts of the given data
x1= df.iloc[0:3,1]
x2= df.iloc[0:3,2]
x3= df.iloc[0:3,3]

# Setting figure colors
cmap = plt.get_cmap("tab20c")
# outer_colors = cmap(np.arange(3)*4)
outer_colors = cmap(np.array([1,5,9]))
inner_colors = cmap(np.array([1,5,9]))
inner_colors1 = cmap(np.array([1,5,9]))
# Setting the size of the figure
plt.figure(figsize=(8,6))

# Plotting the outer pie
plt.pie(x1, labels = df.iloc[0:3, 0], 
       startangle=90, pctdistance =0.88 ,colors=outer_colors,
       autopct = '%1.1f%%', radius= 1.0, labeldistance=1.05,
       textprops ={'fontsize':13},
       wedgeprops = {'linewidth' : 3, 'edgecolor' : "w" } )

# PLotting the inner pie
plt.pie(x2,startangle=90, pctdistance =.85,colors=inner_colors,
        autopct = '%1.1f%%',radius= 0.70,
       textprops ={'fontsize':13}, 
       wedgeprops = {'linewidth' : 3, 'edgecolor' : "w" } )

# PLotting the inner pie2
plt.pie(x3,startangle=90, pctdistance =.50,colors=inner_colors1,
        autopct = '%1.1f%%',radius= 0.45,
        textprops ={'fontsize':13}, 
       wedgeprops = {'linewidth' : 3, 'edgecolor' : "w" } )
# 'fontweight': 'bold' ,
# Creating the donut shape for the pie
centre_circle = plt.Circle((0,0), 0.25, fc='white')
fig= plt.gcf()
fig.gca().add_artist(centre_circle) # adding the centre circle

# Plotting the pie 
plt.axis('equal')  # equal aspect ratio
# plt.legend(loc=3, fontsize =10)
# plt.legend(['Outer Ring (Social Scale)', 'Middle Ring (Knowledge Scale)', 'Inner Ring (Appropriate Action Scale)'])
plt.title('Change in Entry Score (2)\n\nOuter Ring - Social Scale\nMiddle Ring - Knowledge Scale\nInner Ring - Appropriate Action Scale', fontweight='bold')
plt.tight_layout()
plt.show()

# %%
source_data={'students':['No Change','Decreased','Increased'],
'social_scale':[19.790828640386163,8.608205953338697,71.60096540627514],
'knowledge_scale':[31.68023686158401,27.01702442635085,41.302738712065135],
'appropriate_action_scale':[19.797687861271676,13.294797687861271,66.90751445086705]}

# Segregating the raw data into usuable form
df=pd.DataFrame(source_data,columns=
['students','social_scale','knowledge_scale','appropriate_action_scale'])
# df['cumulative_score']=df['social_scale']+df['knowledge_scale']
# +df['appropriate_action_scale']

# Seperating the sub-parts of the given data
x1= df.iloc[0:3,1]
x2= df.iloc[0:3,2]
x3= df.iloc[0:3,3]

# Setting figure colors
cmap = plt.get_cmap("tab20c")
# outer_colors = cmap(np.arange(3)*4)
outer_colors = cmap(np.array([1,5,9]))
inner_colors = cmap(np.array([1,5,9]))
inner_colors1 = cmap(np.array([1,5,9]))
# Setting the size of the figure
plt.figure(figsize=(8,6))

# Plotting the outer pie
plt.pie(x1, labels = df.iloc[0:3, 0], 
       startangle=90, pctdistance =0.88 ,colors=outer_colors,
       autopct = '%1.1f%%', radius= 1.0, labeldistance=1.05,
       textprops ={'fontsize':13},
       wedgeprops = {'linewidth' : 3, 'edgecolor' : "w" } )

# PLotting the inner pie
plt.pie(x2,startangle=90, pctdistance =.85,colors=inner_colors,
        autopct = '%1.1f%%',radius= 0.70,
       textprops ={'fontsize':13}, 
       wedgeprops = {'linewidth' : 3, 'edgecolor' : "w" } )

# PLotting the inner pie2
plt.pie(x3,startangle=90, pctdistance =.50,colors=inner_colors1,
        autopct = '%1.1f%%',radius= 0.45,
        textprops ={'fontsize':13}, 
       wedgeprops = {'linewidth' : 3, 'edgecolor' : "w" } )
# 'fontweight': 'bold' ,
# Creating the donut shape for the pie
centre_circle = plt.Circle((0,0), 0.25, fc='white')
fig= plt.gcf()
fig.gca().add_artist(centre_circle) # adding the centre circle

# Plotting the pie 
plt.axis('equal')  # equal aspect ratio
# plt.legend(loc=3, fontsize =10)
# plt.legend(['Outer Ring (Social Scale)', 'Middle Ring (Knowledge Scale)', 'Inner Ring (Appropriate Action Scale)'])
plt.title('Change in Entry Score (3)\n\nOuter Ring - Social Scale\nMiddle Ring - Knowledge Scale\nInner Ring - Appropriate Action Scale', fontweight='bold')
plt.tight_layout()
plt.show()

# %%
source_data={'students':['No Change','Decreased','Increased'],
'social_scale':[14.339622641509434,10.754716981132075,74.90566037735849],
'knowledge_scale':[18.231441048034934,30.240174672489083,51.52838427947598],
'appropriate_action_scale':[22.284434490481523,16.90929451287794,60.806270996640535]}

# Segregating the raw data into usuable form
df=pd.DataFrame(source_data,columns=
['students','social_scale','knowledge_scale','appropriate_action_scale'])
# df['cumulative_score']=df['social_scale']+df['knowledge_scale']
# +df['appropriate_action_scale']

# Seperating the sub-parts of the given data
x1= df.iloc[0:3,1]
x2= df.iloc[0:3,2]
x3= df.iloc[0:3,3]

# Setting figure colors
cmap = plt.get_cmap("tab20c")
# outer_colors = cmap(np.arange(3)*4)
outer_colors = cmap(np.array([1,5,9]))
inner_colors = cmap(np.array([1,5,9]))
inner_colors1 = cmap(np.array([1,5,9]))
# Setting the size of the figure
plt.figure(figsize=(8,6))

# Plotting the outer pie
plt.pie(x1, labels = df.iloc[0:3, 0], 
       startangle=90, pctdistance =0.88 ,colors=outer_colors,
       autopct = '%1.1f%%', radius= 1.0, labeldistance=1.05,
       textprops ={'fontsize':13},
       wedgeprops = {'linewidth' : 3, 'edgecolor' : "w" } )

# PLotting the inner pie
plt.pie(x2,startangle=90, pctdistance =.85,colors=inner_colors,
        autopct = '%1.1f%%',radius= 0.70,
       textprops ={'fontsize':13}, 
       wedgeprops = {'linewidth' : 3, 'edgecolor' : "w" } )

# PLotting the inner pie2
plt.pie(x3,startangle=90, pctdistance =.50,colors=inner_colors1,
        autopct = '%1.1f%%',radius= 0.45,
        textprops ={'fontsize':13}, 
       wedgeprops = {'linewidth' : 3, 'edgecolor' : "w" } )
# 'fontweight': 'bold' ,
# Creating the donut shape for the pie
centre_circle = plt.Circle((0,0), 0.25, fc='white')
fig= plt.gcf()
fig.gca().add_artist(centre_circle) # adding the centre circle

# Plotting the pie 
plt.axis('equal')  # equal aspect ratio
# plt.legend(loc=3, fontsize =10)
# plt.legend(['Outer Ring (Social Scale)', 'Middle Ring (Knowledge Scale)', 'Inner Ring (Appropriate Action Scale)'])
plt.title('Change in Entry Score (4)\n\nOuter Ring - Social Scale\nMiddle Ring - Knowledge Scale\nInner Ring - Appropriate Action Scale', fontweight='bold')
plt.tight_layout()
plt.show()

# %%
source_data={'students':['No Change','Decreased','Increased'],
'social_scale':[21.91358024691358,6.944444444444445,71.14197530864197],
'knowledge_scale':[21.83206106870229,29.00763358778626,49.16030534351145],
'appropriate_action_scale':[13.54515050167224,22.40802675585284,64.04682274247492]}

# Segregating the raw data into usuable form
df=pd.DataFrame(source_data,columns=
['students','social_scale','knowledge_scale','appropriate_action_scale'])
# df['cumulative_score']=df['social_scale']+df['knowledge_scale']
# +df['appropriate_action_scale']

# Seperating the sub-parts of the given data
x1= df.iloc[0:3,1]
x2= df.iloc[0:3,2]
x3= df.iloc[0:3,3]

# Setting figure colors
cmap = plt.get_cmap("tab20c")
# outer_colors = cmap(np.arange(3)*4)
outer_colors = cmap(np.array([1,5,9]))
inner_colors = cmap(np.array([1,5,9]))
inner_colors1 = cmap(np.array([1,5,9]))
# Setting the size of the figure
plt.figure(figsize=(8,6))

# Plotting the outer pie
plt.pie(x1, labels = df.iloc[0:3, 0], 
       startangle=90, pctdistance =0.88 ,colors=outer_colors,
       autopct = '%1.1f%%', radius= 1.0, labeldistance=1.05,
       textprops ={'fontsize':13},
       wedgeprops = {'linewidth' : 3, 'edgecolor' : "w" } )

# PLotting the inner pie
plt.pie(x2,startangle=90, pctdistance =.85,colors=inner_colors,
        autopct = '%1.1f%%',radius= 0.70,
       textprops ={'fontsize':13}, 
       wedgeprops = {'linewidth' : 3, 'edgecolor' : "w" } )

# PLotting the inner pie2
plt.pie(x3,startangle=90, pctdistance =.50,colors=inner_colors1,
        autopct = '%1.1f%%',radius= 0.45,
        textprops ={'fontsize':13}, 
       wedgeprops = {'linewidth' : 3, 'edgecolor' : "w" } )
# 'fontweight': 'bold' ,
# Creating the donut shape for the pie
centre_circle = plt.Circle((0,0), 0.25, fc='white')
fig= plt.gcf()
fig.gca().add_artist(centre_circle) # adding the centre circle

# Plotting the pie 
plt.axis('equal')  # equal aspect ratio
# plt.legend(loc=3, fontsize =10)
# plt.legend(['Outer Ring (Social Scale)', 'Middle Ring (Knowledge Scale)', 'Inner Ring (Appropriate Action Scale)'])
plt.title('Change in Entry Score (5)\n\nOuter Ring - Social Scale\nMiddle Ring - Knowledge Scale\nInner Ring - Appropriate Action Scale', fontweight='bold')
plt.tight_layout()
plt.show()

# %%
source_data={'students':['No Change','Decreased','Increased'],
'social_scale':[33.81294964028777,6.235011990407674,59.95203836930456],
'knowledge_scale':[26.697892271662766,20.60889929742389,52.693208430913355],
'appropriate_action_scale':[27.17872968980798,16.691285081240768,56.12998522895125]}

# Segregating the raw data into usuable form
df=pd.DataFrame(source_data,columns=
['students','social_scale','knowledge_scale','appropriate_action_scale'])
# df['cumulative_score']=df['social_scale']+df['knowledge_scale']
# +df['appropriate_action_scale']

# Seperating the sub-parts of the given data
x1= df.iloc[0:3,1]
x2= df.iloc[0:3,2]
x3= df.iloc[0:3,3]

# Setting figure colors
cmap = plt.get_cmap("tab20c")
# outer_colors = cmap(np.arange(3)*4)
outer_colors = cmap(np.array([1,5,9]))
inner_colors = cmap(np.array([1,5,9]))
inner_colors1 = cmap(np.array([1,5,9]))
# Setting the size of the figure
plt.figure(figsize=(8,6))

# Plotting the outer pie
plt.pie(x1, labels = df.iloc[0:3, 0], 
       startangle=90, pctdistance =0.88 ,colors=outer_colors,
       autopct = '%1.1f%%', radius= 1.0, labeldistance=1.05,
       textprops ={'fontsize':13},
       wedgeprops = {'linewidth' : 3, 'edgecolor' : "w" } )

# PLotting the inner pie
plt.pie(x2,startangle=90, pctdistance =.85,colors=inner_colors,
        autopct = '%1.1f%%',radius= 0.70,
       textprops ={'fontsize':13}, 
       wedgeprops = {'linewidth' : 3, 'edgecolor' : "w" } )

# PLotting the inner pie2
plt.pie(x3,startangle=90, pctdistance =.50,colors=inner_colors1,
        autopct = '%1.1f%%',radius= 0.45,
        textprops ={'fontsize':13}, 
       wedgeprops = {'linewidth' : 3, 'edgecolor' : "w" } )
# 'fontweight': 'bold' ,
# Creating the donut shape for the pie
centre_circle = plt.Circle((0,0), 0.25, fc='white')
fig= plt.gcf()
fig.gca().add_artist(centre_circle) # adding the centre circle

# Plotting the pie 
plt.axis('equal')  # equal aspect ratio
# plt.legend(loc=3, fontsize =10)
# plt.legend(['Outer Ring (Social Scale)', 'Middle Ring (Knowledge Scale)', 'Inner Ring (Appropriate Action Scale)'])
plt.title('Change in Entry Score (6)\n\nOuter Ring - Social Scale\nMiddle Ring - Knowledge Scale\nInner Ring - Appropriate Action Scale', fontweight='bold')
plt.tight_layout()
plt.show()

# %%
source_data={'students':['No Change','Decreased'],
'social_scale':[88.39779005524862,11.602209944751381],
'knowledge_scale':[85.22727272727273,14.772727272727273],
'appropriate_action_scale':[85.29411764705883,14.705882352941178]}

# Segregating the raw data into usuable form
df=pd.DataFrame(source_data,columns=
['students','social_scale','knowledge_scale','appropriate_action_scale'])
# df['cumulative_score']=df['social_scale']+df['knowledge_scale']
# +df['appropriate_action_scale']

# Seperating the sub-parts of the given data
x1= df.iloc[0:3,1]
x2= df.iloc[0:3,2]
x3= df.iloc[0:3,3]

# Setting figure colors
cmap = plt.get_cmap("tab20c")
# outer_colors = cmap(np.arange(3)*4)
outer_colors = cmap(np.array([1,5,9]))
inner_colors = cmap(np.array([1,5,9]))
inner_colors1 = cmap(np.array([1,5,9]))
# Setting the size of the figure
plt.figure(figsize=(8,6))

# Plotting the outer pie
plt.pie(x1, labels = df.iloc[0:3, 0], 
       startangle=90, pctdistance =0.88 ,colors=outer_colors,
       autopct = '%1.1f%%', radius= 1.0, labeldistance=1.05,
       textprops ={'fontsize':13},
       wedgeprops = {'linewidth' : 3, 'edgecolor' : "w" } )

# PLotting the inner pie
plt.pie(x2,startangle=90, pctdistance =.85,colors=inner_colors,
        autopct = '%1.1f%%',radius= 0.70,
       textprops ={'fontsize':13}, 
       wedgeprops = {'linewidth' : 3, 'edgecolor' : "w" } )

# PLotting the inner pie2
plt.pie(x3,startangle=90, pctdistance =.50,colors=inner_colors1,
        autopct = '%1.1f%%',radius= 0.45,
        textprops ={'fontsize':13}, 
       wedgeprops = {'linewidth' : 3, 'edgecolor' : "w" } )
# 'fontweight': 'bold' ,
# Creating the donut shape for the pie
centre_circle = plt.Circle((0,0), 0.25, fc='white')
fig= plt.gcf()
fig.gca().add_artist(centre_circle) # adding the centre circle

# Plotting the pie 
plt.axis('equal')  # equal aspect ratio
# plt.legend(loc=3, fontsize =10)
# plt.legend(['Outer Ring (Social Scale)', 'Middle Ring (Knowledge Scale)', 'Inner Ring (Appropriate Action Scale)'])
plt.title('Change in Entry Score (7)\n\nOuter Ring - Social Scale\nMiddle Ring - Knowledge Scale\nInner Ring - Appropriate Action Scale', fontweight='bold')
plt.tight_layout()
plt.show()
