# %%
from pandasql import sqldf
from sklearn import datasets
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
project_data = pd.read_excel('../data/TEIS-NSS Project Data 10-2022.xlsx', 
                             sheet_name=['ECO with Exit21-22', 'Elig Timeline Rpt 2018-2022'])

eco_exit = project_data.get('ECO with Exit21-22')
elig_timeline = project_data.get('Elig Timeline Rpt 2018-2022')
print(eco_exit)
print(elig_timeline)
# Out:
#                                                DISTRICT  CHILD_ID  \
# 0                                                    ET  500335.0
# 1                                                    ET  479453.0
# 2                                                    ET  510663.0
# 3                                                    ET  452482.0
# 4                                                    ET  506507.0
# ...                                                 ...       ...
# 8631                                                 UC  514216.0
# 8632                                                NaN       NaN
# 8633                                                NaN       NaN
# 8634                                                NaN       NaN
# 8635  9/29/22 JM Corrected in TEIDS. Progress would ...       NaN
#
#      ECO_Entry_DATE  Ent SOCIAL_SCALE  Ent KNOWLEDGE_SCALE  \
# 0        2021-04-23               5.0                  3.0
# ...

# %%
eco_exit4= eco_exit.rename(columns={'Ent SOCIAL_SCALE' : 'Ent_Social_Scale', 'Exit SOCIAL_SCALE': 'Exit_Social_Scale'})

# %%
print(eco_exit4)
# Out:
#                                                DISTRICT  CHILD_ID  \
# 0                                                    ET  500335.0
# 1                                                    ET  479453.0
# 2                                                    ET  510663.0
# 3                                                    ET  452482.0
# 4                                                    ET  506507.0
# ...                                                 ...       ...
# 8631                                                 UC  514216.0
# 8632                                                NaN       NaN
# 8633                                                NaN       NaN
# 8634                                                NaN       NaN
# 8635  9/29/22 JM Corrected in TEIDS. Progress would ...       NaN
#
#      ECO_Entry_DATE  Ent_Social_Scale  Ent KNOWLEDGE_SCALE  \
# 0        2021-04-23               5.0                  3.0
# ...

# %%
eco_exit2 = eco_exit.iloc[[3,4,5,7,8,9]]
print(eco_exit2)
# Out:
#   DISTRICT  CHILD_ID ECO_Entry_DATE  Ent SOCIAL_SCALE  Ent KNOWLEDGE_SCALE  \
# 3       ET  452482.0     2019-01-31               2.0                  3.0
# 4       ET  506507.0            NaT               NaN                  NaN
# 5       ET  494216.0     2021-01-06               2.0                  4.0
# 7       ET  494502.0     2021-03-01               6.0                  4.0
# 8       ET  488351.0     2020-09-15               5.0                  5.0
# 9       ET  489949.0     2020-10-20               2.0                  1.0
#
#    Ent APPROPRIATE_ACTION_SCALE ECO_Exit_DATE  Exit SOCIAL_SCALE  \
# 3                           3.0    2021-11-22                5.0
# 4                           NaN           NaT                NaN
# 5                           6.0    2021-06-30                4.0
# 7                           5.0    2021-10-15                7.0
# 8                           7.0    2021-02-25                6.0
# ...

# %%
eco_exit3= eco_exit2.rename(columns={'Ent SOCIAL_SCALE' : 'Ent_Social_Scale', 'Exit SOCIAL_SCALE': 'Exit_Social_Scale'})

# %%
q = 'SELECT * FROM eco_exit3'
sqldf(q, globals())
# Out:
#   DISTRICT  CHILD_ID              ECO_Entry_DATE  Ent_Social_Scale  \
# 0       ET  452482.0  2019-01-31 00:00:00.000000               2.0
# 1       ET  506507.0                        None               NaN
# 2       ET  494216.0  2021-01-06 00:00:00.000000               2.0
# 3       ET  494502.0  2021-03-01 00:00:00.000000               6.0
# 4       ET  488351.0  2020-09-15 00:00:00.000000               5.0
# 5       ET  489949.0  2020-10-20 00:00:00.000000               2.0
#
#    Ent KNOWLEDGE_SCALE  Ent APPROPRIATE_ACTION_SCALE  \
# 0                  3.0                           3.0
# 1                  NaN                           NaN
# 2                  4.0                           6.0
# 3                  4.0                           5.0
# 4                  5.0                           7.0
# 5                  1.0                           2.0
#
#                 ECO_Exit_DATE  Exit_Social_Scale  Exit KNOWLEDGE_SCALE  \
# ...
